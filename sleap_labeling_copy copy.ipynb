# %%
from sleap_nn.predict import run_inference
import glob
import tqdm
import re
import os
import sleap_io as sio
import pandas as pd

# %%
# Functions to sort file names correctly
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [atoi(c) for c in re.split(r'(\d+)', text)]

# %%
# Multi head sleap model
centered_instance_model_path = r"D:\sleap-3D\talmo\models\headmic_model\centered_instance_unet_body_1-15"
centroid_model_path = r"D:\sleap-3D\talmo\models\headmic_model\centroid_unet_body_1_anchor-15"

# %%
for exp in [423]:
    
    experiment_no = exp
    folder = f"D:/big_setup/experiment_{experiment_no}/concatenated_data_cam_mic_sync/"
    save_path = folder+"sleap_predictions/"
    os.makedirs(save_path,exist_ok=True)

    vid_files = glob.glob(folder + "*center*.mp4")
    vid_files.sort(key=natural_keys)



    print("Tracking")
    for file in tqdm.tqdm(vid_files):
        
        # Initial
        if any(i in file for i in []):

            print(f"Not running:{file}")
            continue

        else:
            print(f"Running:{file}")

            preds = run_inference(
            data_path=file,
            model_paths=[centroid_model_path, centered_instance_model_path],
            device='cuda',
            make_labels=True,
            output_path=save_path+file.split("\\")[-1]+".pred_body_1_anchor.slp",
            tracking=True,
            candidates_method="local_queues",
            max_tracks=2, #optional
            )
            


        # Second run 
        # if any(i in file for i in ["013","014"]):
            

        #     print(f"Running:{file}")

        #     preds = run_inference(
        #     data_path=file,
        #     model_paths=[centroid_model_path, centered_instance_model_path],
        #     device='cuda',
        #     make_labels=True,
        #     output_path=save_path+file.split("\\")[-1]+".pred_body_1_anchor.slp",
        #     tracking=True,
        #     candidates_method="local_queues",
        #     max_tracks=2, #optional
        #     )
        # else:
        #     print(f"Not running:{file}")
        #     continue
    

    print(f"Done with experiment: {exp}")
# Out:
# Tracking
#   0%|          | 0/15 [00:00<?, ?it/s]
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_000.mp4
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_001.mp4
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_002.mp4
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_003.mp4
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_004.mp4
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_005.mp4
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_006.mp4
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_007.mp4
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_008.mp4
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_009.mp4
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_010.mp4
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_011.mp4
# Not running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_012.mp4
# Running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_013.mp4
# 2026-03-14 13:45:15 | INFO | sleap_nn.predict:run_inference:319 | Started inference at: 2026-03-14 13:45:15.341831
# 2026-03-14 13:45:15 | INFO | sleap_nn.predict:run_inference:335 | Using device: cuda
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2026-03-14 13:47:05 | INFO | sleap_nn.predict:run_inference:453 | Finished inference at: 2026-03-14 13:47:05.553111
# 2026-03-14 13:47:05 | INFO | sleap_nn.predict:run_inference:454 | Total runtime: 110.21127986907959 secs
#  93%|█████████▎| 14/15 [01:50<00:07,  7.91s/it]
# 2026-03-14 13:47:05 | INFO | sleap_nn.predict:run_inference:465 | Predictions output path: D:/big_setup/experiment_423/concatenated_data_cam_mic_sync/sleap_predictions/video_gily_center_013.mp4.pred_body_1_anchor.slp
# 2026-03-14 13:47:05 | INFO | sleap_nn.predict:run_inference:466 | Saved file at: 2026-03-14 13:47:05.979993
# Running:D:/big_setup/experiment_423/concatenated_data_cam_mic_sync\video_gily_center_014.mp4
# 2026-03-14 13:47:06 | INFO | sleap_nn.predict:run_inference:319 | Started inference at: 2026-03-14 13:47:06.021111
# 2026-03-14 13:47:06 | INFO | sleap_nn.predict:run_inference:335 | Using device: cuda
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2026-03-14 13:48:42 | INFO | sleap_nn.predict:run_inference:453 | Finished inference at: 2026-03-14 13:48:42.909052
# 2026-03-14 13:48:42 | INFO | sleap_nn.predict:run_inference:454 | Total runtime: 96.88794112205505 secs
# 100%|██████████| 15/15 [03:28<00:00, 13.87s/it]
# 2026-03-14 13:48:43 | INFO | sleap_nn.predict:run_inference:465 | Predictions output path: D:/big_setup/experiment_423/concatenated_data_cam_mic_sync/sleap_predictions/video_gily_center_014.mp4.pred_body_1_anchor.slp
# 2026-03-14 13:48:43 | INFO | sleap_nn.predict:run_inference:466 | Saved file at: 2026-03-14 13:48:43.317211
# Done with experiment: 423

# %% [markdown]
# ### Making csv files from outputs

# %%
for exp in [389]:
    folder = f"D:/big_setup/experiment_{exp}/concatenated_data_cam_mic_sync/"
    labels_path = folder+"sleap_predictions/"
    tracks_path = folder+"tracks/"
    os.makedirs(tracks_path,exist_ok=True)

    labels = glob.glob(labels_path+"*.slp")
    for label in tqdm.tqdm(labels):
        preds = sio.load_file(label)
        tmp_str = label.split("\\")[-1].split(".")[0]
        sio.save_csv(preds,tracks_path+"labels.body_1_anchor."+tmp_str+".analysis.csv",save_metadata= True)
        # data = sio.load_csv(tracks_path+"labels.body_1_anchor."+tmp_str+".analysis.csv")
        # data.save(tracks_path+"labels.body_1_anchor."+tmp_str+".analysis.csv.slp")
        
    print(f"Experiment {exp} done")
# Out:
# 100%|██████████| 8/8 [00:04<00:00,  1.93it/s]
# Experiment 389 done

# %%
# for exp in [383,384]:
#     folder = f"D:/big_setup/experiment_{exp}/concatenated_data_cam_mic_sync/"
#     labels_path = folder+"sleap_predictions/"
#     tracks_path = folder+"tracks/"
#     os.makedirs(tracks_path,exist_ok=True)

#     labels = glob.glob(labels_path+"*.slp")
#     for label in tqdm.tqdm(labels):
#         preds = sio.load_file(label)
#         data = {}
#         for frame in preds.labeled_frames:
#             for instance in frame.instances:
#                 if len(data) == 0:
#                     data["track"] = [instance.track.name]
#                     data["frame_idx"] = [frame.frame_idx]
#                     data["instance.score"] = [instance.score]
#                     for entry in instance.points:
#                         data[f"{entry[-1]}.x"] = [entry[0][0]]
#                         data[f"{entry[-1]}.y"] = [entry[0][1]]
#                         data[f"{entry[-1]}.score"] = [entry[1]]
#                 else:
#                     data["track"].append(instance.track.name)
#                     data["frame_idx"].append(frame.frame_idx)
#                     data["instance.score"].append(instance.score)
#                     for entry in instance.points:
#                         data[f"{entry[-1]}.x"].append(entry[0][0])
#                         data[f"{entry[-1]}.y"].append(entry[0][1])
#                         data[f"{entry[-1]}.score"].append(entry[1])
    
#         df = pd.DataFrame.from_dict(data)
#         df.to_csv(tracks_path+"labels.body_1_anchor."+label.split("\\")[-1].split(".")[0]+".tracks.csv",index=False)
#     print(f"Experiment {exp} done")
# Out:
# 100%|██████████| 8/8 [00:02<00:00,  3.41it/s]
# Experiment 383 done
# 100%|██████████| 7/7 [00:03<00:00,  1.98it/s]
# Experiment 384 done
