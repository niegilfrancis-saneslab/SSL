# %%
from sleap_nn.predict import run_inference
import glob
import tqdm
import re
import os
import sleap_io as sio
import pandas as pd

# %%
# Functions to sort file names correctly
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [atoi(c) for c in re.split(r'(\d+)', text)]

# %%
centered_instance_model_path = r"D:\sleap-3D\talmo\models\headmic_model\centered_instance_unet_body_1-15"
centroid_model_path = r"D:\sleap-3D\talmo\models\headmic_model\centroid_unet_body_1_anchor-15"

# %%
for exp in [420]:
    
    experiment_no = exp
    folder = f"D:/big_setup/experiment_{experiment_no}/concatenated_data_cam_mic_sync/"
    save_path = folder+"sleap_predictions/"
    os.makedirs(save_path,exist_ok=True)

    vid_files = glob.glob(folder + "*center*.mp4")
    vid_files.sort(key=natural_keys)



    print("Tracking")
    for file in tqdm.tqdm(vid_files):
        
        # Initial
        if any(i in file for i in []): #"000","001","002","003","004","005","006","007","008","009","010","011","012","013","014","015","016","017"

            print(f"Not running:{file}")
            continue

        else:
            print(f"Running:{file}")

            preds = run_inference(
            data_path=file,
            model_paths=[centroid_model_path, centered_instance_model_path],
            device='cuda',
            make_labels=True,
            output_path=save_path+file.split("\\")[-1]+".pred_body_1_anchor.slp",
            tracking=True,
            candidates_method="local_queues",
            max_tracks=2, #optional
            )
            


        # Second run 
        # if any(i in file for i in ["004","018","020","028","029"]):
            

        #     print(f"Running:{file}")

        #     preds = run_inference(
        #     data_path=file,
        #     model_paths=[centroid_model_path, centered_instance_model_path],
        #     device='cuda',
        #     make_labels=True,
        #     output_path=save_path+file.split("\\")[-1]+".pred_body_1_anchor.slp",
        #     tracking=True,
        #     candidates_method="local_queues",
        #     max_tracks=2, #optional
        #     )
        # else:
        #     print(f"Not running:{file}")
        #     continue
    

    print(f"Done with experiment: {exp}")
# Out:
# Tracking
#   0%|          | 0/38 [00:00<?, ?it/s]
# Running:D:/big_setup/experiment_420/concatenated_data_cam_mic_sync\video_gily_center_000.mp4
# 2026-03-13 14:11:14 | INFO | sleap_nn.predict:run_inference:319 | Started inference at: 2026-03-13 14:11:14.933408
# 2026-03-13 14:11:14 | INFO | sleap_nn.predict:run_inference:335 | Using device: cuda
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2026-03-13 14:13:26 | INFO | sleap_nn.predict:run_inference:453 | Finished inference at: 2026-03-13 14:13:26.104198
# 2026-03-13 14:13:26 | INFO | sleap_nn.predict:run_inference:454 | Total runtime: 131.1707901954651 secs
#   3%|▎         | 1/38 [02:11<1:21:06, 131.52s/it]
# 2026-03-13 14:13:26 | INFO | sleap_nn.predict:run_inference:465 | Predictions output path: D:/big_setup/experiment_420/concatenated_data_cam_mic_sync/sleap_predictions/video_gily_center_000.mp4.pred_body_1_anchor.slp
# 2026-03-13 14:13:26 | INFO | sleap_nn.predict:run_inference:466 | Saved file at: 2026-03-13 14:13:26.436320
# Running:D:/big_setup/experiment_420/concatenated_data_cam_mic_sync\video_gily_center_001.mp4
# 2026-03-13 14:13:26 | INFO | sleap_nn.predict:run_inference:319 | Started inference at: 2026-03-13 14:13:26.456631
# 2026-03-13 14:13:26 | INFO | sleap_nn.predict:run_inference:335 | Using device: cuda
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2026-03-13 14:15:35 | INFO | sleap_nn.predict:run_inference:453 | Finished inference at: 2026-03-13 14:15:35.997937
# 2026-03-13 14:15:35 | INFO | sleap_nn.predict:run_inference:454 | Total runtime: 129.54130625724792 secs
#   5%|▌         | 2/38 [04:21<1:18:20, 130.58s/it]
# 2026-03-13 14:15:36 | INFO | sleap_nn.predict:run_inference:465 | Predictions output path: D:/big_setup/experiment_420/concatenated_data_cam_mic_sync/sleap_predictions/video_gily_center_001.mp4.pred_body_1_anchor.slp
# 2026-03-13 14:15:36 | INFO | sleap_nn.predict:run_inference:466 | Saved file at: 2026-03-13 14:15:36.331568
# Running:D:/big_setup/experiment_420/concatenated_data_cam_mic_sync\video_gily_center_002.mp4
# 2026-03-13 14:15:36 | INFO | sleap_nn.predict:run_inference:319 | Started inference at: 2026-03-13 14:15:36.376808
# 2026-03-13 14:15:36 | INFO | sleap_nn.predict:run_inference:335 | Using device: cuda
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2026-03-13 14:17:55 | INFO | sleap_nn.predict:run_inference:453 | Finished inference at: 2026-03-13 14:17:55.701505
# 2026-03-13 14:17:55 | INFO | sleap_nn.predict:run_inference:454 | Total runtime: 139.32469654083252 secs
#   8%|▊         | 3/38 [06:41<1:18:37, 134.79s/it]
# 2026-03-13 14:17:56 | INFO | sleap_nn.predict:run_inference:465 | Predictions output path: D:/big_setup/experiment_420/concatenated_data_cam_mic_sync/sleap_predictions/video_gily_center_002.mp4.pred_body_1_anchor.slp
# 2026-03-13 14:17:56 | INFO | sleap_nn.predict:run_inference:466 | Saved file at: 2026-03-13 14:17:56.076460
# Running:D:/big_setup/experiment_420/concatenated_data_cam_mic_sync\video_gily_center_003.mp4
# 2026-03-13 14:17:56 | INFO | sleap_nn.predict:run_inference:319 | Started inference at: 2026-03-13 14:17:56.178500
# 2026-03-13 14:17:56 | INFO | sleap_nn.predict:run_inference:335 | Using device: cuda
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2026-03-13 14:20:10 | INFO | sleap_nn.predict:run_inference:453 | Finished inference at: 2026-03-13 14:20:10.132032
# 2026-03-13 14:20:10 | INFO | sleap_nn.predict:run_inference:454 | Total runtime:
# 2026-03-13 15:49:44 | INFO | sleap_nn.predict:run_inference:466 | Saved file at: 2026-03-13 15:49:44.905664
# Done with experiment: 420

# %% [markdown]
# ### Making csv files from outputs

# %%
for exp in [384]:
    folder = f"D:/big_setup/experiment_{exp}/concatenated_data_cam_mic_sync/"
    labels_path = folder+"sleap_predictions/"
    tracks_path = folder+"tracks/"
    os.makedirs(tracks_path,exist_ok=True)

    labels = glob.glob(labels_path+"*.slp")
    for label in tqdm.tqdm(labels):
        # !sleap-convert {label} -o {tracks_path+label.split("\\")[-1].split(".")[0]+".tracks.h5"} --format analysis.h5

        preds = sio.load_file(label)
        data = {}
        for frame in preds.labeled_frames:
            for instance in frame.instances:
                if len(data) == 0:
                    data["track"] = [instance.track.name]
                    data["frame_idx"] = [frame.frame_idx]
                    data["instance.score"] = [instance.score]
                    for entry in instance.points:
                        data[f"{entry[-1]}.x"] = [entry[0][0]]
                        data[f"{entry[-1]}.y"] = [entry[0][1]]
                        data[f"{entry[-1]}.score"] = [entry[1]]
                else:
                    data["track"].append(instance.track.name)
                    data["frame_idx"].append(frame.frame_idx)
                    data["instance.score"].append(instance.score)
                    for entry in instance.points:
                        data[f"{entry[-1]}.x"].append(entry[0][0])
                        data[f"{entry[-1]}.y"].append(entry[0][1])
                        data[f"{entry[-1]}.score"].append(entry[1])
    
        df = pd.DataFrame.from_dict(data)
        df.to_csv(tracks_path+"labels.body_1_anchor."+label.split("\\")[-1].split(".")[0]+".analysis.csv",index=False)
    print(f"Experiment {exp} done")
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:15<01:34, 15.75s/it]
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 9
# 	edge_names: 8
# 	edge_inds: 8
# 	tracks: (3600, 9, 2, 2)
# 	track_occupancy: (2, 3600)
# 	point_scores: (3600, 9, 2)
# 	instance_scores: (3600, 2)
# 	tracking_scores: (3600, 2)
# 	labels_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/sleap_predictions\video_gily_center_000.mp4.pred_body_1_anchor.slp
# 	video_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/video_gily_center_000.mp4
# 	video_ind: 0
# 	provenance: {}
# Saved as D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/tracks/video_gily_center_000.tracks.h5
#  29%|██▊       | 2/7 [00:32<01:20, 16.06s/it]
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 9
# 	edge_names: 8
# 	edge_inds: 8
# 	tracks: (3600, 9, 2, 2)
# 	track_occupancy: (2, 3600)
# 	point_scores: (3600, 9, 2)
# 	instance_scores: (3600, 2)
# 	tracking_scores: (3600, 2)
# 	labels_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/sleap_predictions\video_gily_center_001.mp4.pred_body_1_anchor.slp
# 	video_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/video_gily_center_001.mp4
# 	video_ind: 0
# 	provenance: {}
# Saved as D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/tracks/video_gily_center_001.tracks.h5
#  43%|████▎     | 3/7 [00:48<01:05, 16.42s/it]
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 9
# 	edge_names: 8
# 	edge_inds: 8
# 	tracks: (3600, 9, 2, 2)
# 	track_occupancy: (2, 3600)
# 	point_scores: (3600, 9, 2)
# 	instance_scores: (3600, 2)
# 	tracking_scores: (3600, 2)
# 	labels_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/sleap_predictions\video_gily_center_002.mp4.pred_body_1_anchor.slp
# 	video_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/video_gily_center_002.mp4
# 	video_ind: 0
# 	provenance: {}
# Saved as D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/tracks/video_gily_center_002.tracks.h5
#  57%|█████▋    | 4/7 [01:10<00:55, 18.65s/it]
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 9
# 	edge_names: 8
# 	edge_inds: 8
# 	tracks: (3600, 9, 2, 2)
# 	track_occupancy: (2, 3600)
# 	point_scores: (3600, 9, 2)
# 	instance_scores: (3600, 2)
# 	tracking_scores: (3600, 2)
# 	labels_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/sleap_predictions\video_gily_center_003.mp4.pred_body_1_anchor.slp
# 	video_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/video_gily_center_003.mp4
# 	video_ind: 0
# 	provenance: {}
# Saved as D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/tracks/video_gily_center_003.tracks.h5
#  71%|███████▏  | 5/7 [01:19<00:30, 15.10s/it]
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 9
# 	edge_names: 8
# 	edge_inds: 8
# 	tracks: (3600, 9, 2, 2)
# 	track_occupancy: (2, 3600)
# 	point_scores: (3600, 9, 2)
# 	instance_scores: (3600, 2)
# 	tracking_scores: (3600, 2)
# 	labels_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/sleap_predictions\video_gily_center_004.mp4.pred_body_1_anchor.slp
# 	video_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/video_gily_center_004.mp4
# 	video_ind: 0
# 	provenance: {}
# Saved as D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/tracks/video_gily_center_004.tracks.h5
#  86%|████████▌ | 6/7 [01:31<00:13, 13.92s/it]
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 9
# 	edge_names: 8
# 	edge_inds: 8
# 	tracks: (3600, 9, 2, 2)
# 	track_occupancy: (2, 3600)
# 	point_scores: (3600, 9, 2)
# 	instance_scores: (3600, 2)
# 	tracking_scores: (3600, 2)
# 	labels_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/sleap_predictions\video_gily_center_005.mp4.pred_body_1_anchor.slp
# 	video_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/video_gily_center_005.mp4
# 	video_ind: 0
# 	provenance: {}
# Saved as D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/tracks/video_gily_center_005.tracks.h5
# 100%|██████████| 7/7 [01:42<00:00, 14.58s/it]
# Exporting to SLEAP Analysis file...
# 	track_names: 4
# 	node_names: 9
# 	edge_names: 8
# 	edge_inds: 8
# 	tracks: (2759, 9, 2, 4)
# 	track_occupancy: (4, 2759)
# 	point_scores: (2759, 9, 4)
# 	instance_scores: (2759, 4)
# 	tracking_scores: (2759, 4)
# 	labels_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/sleap_predictions\video_gily_center_006.mp4.pred_body_1_anchor.slp
# 	video_path: D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/video_gily_center_006.mp4
# 	video_ind: 0
# 	provenance: {}
# Saved as D:/big_setup/experiment_384/concatenated_data_cam_mic_sync/tracks/video_gily_center_006.tracks.h5
