# %%
import shutil
import os

# %%
for i in range(281,289):
    original_path = f"D:/big_setup/experiment_{i}/concatenated_data_cam_mic_sync/ssl_data_path"

    # Define source and destination paths
    
    destination_directory = f"D:/big_setup/ssl_data/experiment_{i}/"

    # Create the destination directory if it doesn't exist
    #os.makedirs(destination_directory, exist_ok=True)


    # Copy the file and rename it
    shutil.copytree(original_path, destination_directory)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 13
#       6 destination_directory = f"D:/big_setup/ssl_data/experiment_{i}/"
#       8 # Create the destination directory if it doesn't exist
#       9 #os.makedirs(destination_directory, exist_ok=True)
#      10
#      11
#      12 # Copy the file and rename it
# ---> 13 shutil.copytree(original_path, destination_directory)
#
# File c:\Users\DAQ3\miniforge3\envs\venv\Lib\shutil.py:573, in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     571 with os.scandir(src) as itr:
#     572     entries = list(itr)
# --> 573 return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     574                  ignore=ignore, copy_function=copy_function,
#     575                  ignore_dangling_symlinks=ignore_dangling_symlinks,
# ...
